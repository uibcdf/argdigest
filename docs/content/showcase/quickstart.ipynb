# %% [markdown]
# # Quickstart — ArgDigest in action
#
# This notebook shows a minimal example of how to use `@digest`.

# %%
from argdigest import digest

@digest(map={"x": {"kind": "vector", "rules": ["ensure_list"]}})
def process(x):
    return x
